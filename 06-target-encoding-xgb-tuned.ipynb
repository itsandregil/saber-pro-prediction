# %% [markdown]
# ## Experimento No 6 - Different Preprocessing

# %% [markdown]
# ### Load data and import libraries

# %%
# In case you're running this in colab
# !pip install pycaret
# !pip install dython
# !pip install optuna

# %%
# Data exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Modeling
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, TargetEncoder
from xgboost import XGBClassifier

# Evaluation
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score

# Hyper-parameter tuning
import optuna

# Configurations
RANDOM_SEED = 42 # For reproducibility

sns.set_palette('pastel')
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 50)

# %%
df_train_full = pd.read_csv('data/train.csv')
df_test_full = pd.read_csv('data/test.csv')
df_train_full.head().T
# Out:
#                                                                        0  \
# ID                                                                904256
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                           ENFERMERIA
# ESTU_PRGM_DEPARTAMENTO                                            BOGOTÁ
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 5.5 millones y menos de 7 millones
# ESTU_HORASSEMANATRABAJA                                Menos de 10 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                     Técnica o tecnológica incompleta
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   Si
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                                            Postgrado
# RENDIMIENTO_GLOBAL                                            medio-alto
#
#                                                                        1  \
# ID                                                                645256
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                              DERECHO
# ESTU_PRGM_DEPARTAMENTO                                         ATLANTICO
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                                                0
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    No
# FAMI_EDUCACIONPADRE                       Técnica o tecnológica completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  No
# FAMI_EDUCACIONMADRE                     Técnica o tecnológica incompleta
# RENDIMIENTO_GLOBAL                                                  bajo
#
#                                                                        2  \
# ID                                                                308367
# PERIODO                                                            20203
# ESTU_PRGM_ACADEMICO                                MERCADEO Y PUBLICIDAD
# ESTU_PRGM_DEPARTAMENTO                                            BOGOTÁ
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                                  Más de 30 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                   Secundaria (Bachillerato) completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  No
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                   Secundaria (Bachillerato) completa
# RENDIMIENTO_GLOBAL                                                  bajo
#
#                                                                        3  \
# ID                                                                470353
# PERIODO                                                            20195
# ESTU_PRGM_ACADEMICO                           ADMINISTRACION DE EMPRESAS
# ESTU_PRGM_DEPARTAMENTO                                         SANTANDER
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 4 millones y menos de 5.5 millones
# ESTU_HORASSEMANATRABAJA                                                0
# FAMI_ESTRATOVIVIENDA                                           Estrato 4
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                                              No sabe
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                   Secundaria (Bachillerato) completa
# RENDIMIENTO_GLOBAL                                                  alto
#
#                                                                        4
# ID                                                                989032
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                           PSICOLOGIA
# ESTU_PRGM_DEPARTAMENTO                                         ANTIOQUIA
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                              Entre 21 y 30 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                                    Primaria completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   Si
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                                    Primaria completa
# RENDIMIENTO_GLOBAL                                            medio-bajo

# %%
df_analysis = df_train_full.copy()

# %%
df_analysis.isna().sum().sort_values(ascending=False)
# Out:
# FAMI_TIENEAUTOMOVIL               43623
# FAMI_TIENELAVADORA                39773
# FAMI_TIENECOMPUTADOR              38103
# FAMI_ESTRATOVIVIENDA              32137
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_TIENEINTERNET.1              26629
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONMADRE               23664
# FAMI_EDUCACIONPADRE               23178
# ESTU_PAGOMATRICULAPROPIO           6498
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ID                                    0
# ESTU_PRIVADO_LIBERTAD                 0
# PERIODO                               0
# ESTU_PRGM_DEPARTAMENTO                0
# ESTU_PRGM_ACADEMICO                   0
# RENDIMIENTO_GLOBAL                    0
# dtype: int64

# %% [markdown]
# ### Preprocessing

# %%
def normalize_text(text: str):
    """Removes any weird character like accents from a string"""
    import unicodedata

    if not pd.isna(text):
        return (
            unicodedata.normalize('NFKD', text)
            .encode('ASCII', 'ignore')
            .decode('utf-8')
        )
    return text

def clean_data(df: pd.DataFrame) -> pd.DataFrame: 
    new_df = df.copy() # Create a copy

    # Drop and clean columns
    new_df.drop(['ID', 'FAMI_TIENEINTERNET.1', 'ESTU_PRIVADO_LIBERTAD'], axis=1, inplace=True)

    # Change data types
    new_df['PERIODO'] = new_df['PERIODO'].astype(str)
    
    # Remove weird characters from values
    for col in ['ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE']:
        new_df[col] = new_df[col].apply(normalize_text)

    # Replace values to make more sense
    new_df['ESTU_HORASSEMANATRABAJA'].replace('0', 'No trabaja', inplace=True)
    new_df['FAMI_EDUCACIONPADRE'].replace(['No Aplica', 'No sabe'], 'Ninguno', inplace=True)
    new_df['FAMI_EDUCACIONMADRE'].replace(['No Aplica', 'No sabe'], 'Ninguno', inplace=True)

    return new_df

def impute_cols(df: pd.DataFrame):
    new_df = df.copy() # Make a copy

    # Impute with own values
    new_df['FAMI_ESTRATOVIVIENDA'] = new_df['FAMI_ESTRATOVIVIENDA'].fillna('Unknown') # 'Sin Estrato' or mode or 'Unknown'
    new_df['ESTU_HORASSEMANATRABAJA'] = new_df['ESTU_HORASSEMANATRABAJA'].fillna('No trabaja') # No trabaja or Unknown
    new_df['FAMI_EDUCACIONPADRE'] = new_df['FAMI_EDUCACIONPADRE'].fillna('Ninguno') # Same as with MADRE
    new_df['FAMI_EDUCACIONMADRE'] = new_df['FAMI_EDUCACIONMADRE'].fillna('Ninguno') # Otra opcion: Ninguno or Unknown
 
    # Select binary columns
    # For VALORMATRICULA values could be 'No pago matricula' or Mode or Unknown (We'll go we the mode first)
    binary_cols = [col for col in new_df.columns if new_df[col].nunique() == 2]
    for col in binary_cols + ['ESTU_VALORMATRICULAUNIVERSIDAD']:
        col_mode = new_df[col].mode()[0]
        new_df[col] = new_df[col].fillna(col_mode)

    return new_df

# %%
# Clean the training and testing datasets
df_train = clean_data(df_train_full)
df_test = clean_data(df_test_full)

# %%
# Impute values in training and testing datasets
df_train = impute_cols(df_train)
df_test = impute_cols(df_test)

# %%
df_train.shape
# Out:
# (692500, 14)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   PERIODO                         692500 non-null  object
#  1   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  2   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  3   ESTU_VALORMATRICULAUNIVERSIDAD  692500 non-null  object
#  4   ESTU_HORASSEMANATRABAJA         692500 non-null  object
#  5   FAMI_ESTRATOVIVIENDA            692500 non-null  object
#  6   FAMI_TIENEINTERNET              692500 non-null  object
#  7   FAMI_EDUCACIONPADRE             692500 non-null  object
#  8   FAMI_TIENELAVADORA              692500 non-null  object
#  9   FAMI_TIENEAUTOMOVIL             692500 non-null  object
#  10  ESTU_PAGOMATRICULAPROPIO        692500 non-null  object
#  11  FAMI_TIENECOMPUTADOR            692500 non-null  object
#  12  FAMI_EDUCACIONMADRE             692500 non-null  object
#  13  RENDIMIENTO_GLOBAL              692500 non-null  object
# dtypes: object(14)
# memory usage: 74.0+ MB

# %% [markdown]
# #### Encoding

# %%
# Define encoders in a global scope to use them
# after they were fitted with the data.
label_encoder = LabelEncoder()
target_encoder = TargetEncoder(target_type='multiclass', random_state=RANDOM_SEED)

def preprocess_data(X: pd.DataFrame, y: pd.Series = None) -> pd.DataFrame():
    """
    Turns features and target into numeric values applying an encoding for each
    column.
    """
    X = X.copy() # Make copy of the features
    y_encoded = None
    
    high_card_cols = ['ESTU_PRGM_ACADEMICO']
    # Check if target was provided
    if y is not None:
        # Label encoding
        y_encoded = pd.Series(label_encoder.fit_transform(y))
        
        # Target encoding for training using the encoded labels
        # We need to fit and transform the data here.
        target_encoder.fit(X[high_card_cols], y_encoded)
        new_features_names = target_encoder.get_feature_names_out()
        df_target_encoded = pd.DataFrame(target_encoder.transform(X[high_card_cols]), columns=new_features_names)
        
        X = pd.concat([X.drop('ESTU_PRGM_ACADEMICO', axis=1), df_target_encoded], axis=1)
    else:
        # Target encoding for testing dataset just using transform
        new_features_names = target_encoder.get_feature_names_out()
        df_target_encoded = pd.DataFrame(target_encoder.transform(X[high_card_cols]), columns=new_features_names)
        X = pd.concat([X.drop('ESTU_PRGM_ACADEMICO', axis=1), df_target_encoded], axis=1)
        

    # Ordinal encoding
    ord_encoder = OrdinalEncoder() # Ordinal Encoder
    ord_cols = ['FAMI_ESTRATOVIVIENDA','ESTU_PRGM_DEPARTAMENTO']    
    df_ordinal = pd.DataFrame(ord_encoder.fit_transform(X[ord_cols]), columns=ord_cols)
    
    for col in ord_cols:
        max_val = df_ordinal[col].max()
        df_ordinal[col] = df_ordinal[col].map(lambda x: x / max_val) # Normalize values 0 - 1

    X = pd.concat([X.drop(ord_cols, axis=1), df_ordinal], axis=1)

    # Binary encoding
    bin_cols = [col for col in X.columns if X[col].nunique() == 2]

    for col in bin_cols:
        X[col] = X[col].replace({'Si': 1, 'No': 0})
    
    # One-hot encoding
    X = pd.get_dummies(X, dtype=int)

    return X, y_encoded

# %%
# Split train data into features and target
X = df_train.drop('RENDIMIENTO_GLOBAL', axis=1)
y = df_train.RENDIMIENTO_GLOBAL

# %%
# Encode features and target (for training dataset)
X, y_encoded = preprocess_data(X, y)
X_test, _ = preprocess_data(X=df_test)

# %%
X.shape, X_test.shape
# Out:
# ((692500, 53), (296786, 53))

# %%
type(y_encoded)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Model Creation
#
# At this point we are going to try a **XGBClassifier** to see how the preprocessing improve the accuracy

# %% [markdown]
# ## Hyper-parameters Tuning

# %%
def xgb_objective(trial):
    
    # Create params
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1500),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.1)
    }
    # Set params to the model and train the new model
    model = XGBClassifier(**params)

    # Split data
    X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=RANDOM_SEED)

    # Fit the model
    model.fit(X_train, y_train)

    # Evaluate
    preds = model.predict(X_val)
    acc = accuracy_score(y_val, preds)

    return acc

# %%
study = optuna.create_study(direction='maximize')
study.optimize(xgb_objective, n_trials=30)
# Out:
# [I 2024-06-01 00:09:45,030] A new study created in memory with name: no-name-1dabe894-38a0-4935-9a98-5c8907bd7264
# [I 2024-06-01 00:10:18,290] Trial 0 finished with value: 0.4347364620938628 and parameters: {'n_estimators': 820, 'learning_rate': 0.014971915185781455}. Best is trial 0 with value: 0.4347364620938628.
# [I 2024-06-01 00:10:26,988] Trial 1 finished with value: 0.42691696750902525 and parameters: {'n_estimators': 196, 'learning_rate': 0.026382990281506116}. Best is trial 0 with value: 0.4347364620938628.
# [I 2024-06-01 00:10:52,714] Trial 2 finished with value: 0.4408375451263538 and parameters: {'n_estimators': 671, 'learning_rate': 0.05107725421938646}. Best is trial 2 with value: 0.4408375451263538.
# [I 2024-06-01 00:11:06,773] Trial 3 finished with value: 0.4398916967509025 and parameters: {'n_estimators': 341, 'learning_rate': 0.07097333672431641}. Best is trial 2 with value: 0.4408375451263538.
# [I 2024-06-01 00:11:58,545] Trial 4 finished with value: 0.4405920577617328 and parameters: {'n_estimators': 1331, 'learning_rate': 0.020078340787585313}. Best is trial 2 with value: 0.4408375451263538.
# [I 2024-06-01 00:12:52,912] Trial 5 finished with value: 0.4386498194945848 and parameters: {'n_estimators': 1378, 'learning_rate': 0.014602143726048688}. Best is trial 2 with value: 0.4408375451263538.
# [I 2024-06-01 00:13:34,905] Trial 6 finished with value: 0.4371335740072202 and parameters: {'n_estimators': 1066, 'learning_rate': 0.015426109764026643}. Best is trial 2 with value: 0.4408375451263538.
# [I 2024-06-01 00:14:24,827] Trial 7 finished with value: 0.4419638989169675 and parameters: {'n_estimators': 1395, 'learning_rate': 0.056714858759883545}. Best is trial 7 with value: 0.4419638989169675.
# [I 2024-06-01 00:14:55,060] Trial 8 finished with value: 0.44026714801444045 and parameters: {'n_estimators': 741, 'learning_rate': 0.03079495987622915}. Best is trial 7 with value: 0.4419638989169675.
# [I 2024-06-01 00:15:38,249] Trial 9 finished with value: 0.43787725631768953 and parameters: {'n_estimators': 1091, 'learning_rate': 0.017610113312463614}. Best is trial 7 with value: 0.4419638989169675.
# [I 2024-06-01 00:16:32,842] Trial 10 finished with value: 0.44170397111913356 and parameters: {'n_estimators': 1470, 'learning_rate': 0.09764972160940691}. Best is trial 7 with value: 0.4419638989169675.
# [I 2024-06-01 00:17:26,705] Trial 11 finished with value: 0.44150902527075814 and parameters: {'n_estimators': 1395, 'learning_rate': 0.0929015380284924}. Best is trial 7 with value: 0.4419638989169675.
# [I 2024-06-01 00:18:24,207] Trial 12 finished with value: 0.44219494584837543 and parameters: {'n_estimators': 1497, 'learning_rate': 0.05121028539739568}. Best is trial 12 with value: 0.44219494584837543.
# [I 2024-06-01 00:19:06,040] Trial 13 finished with value: 0.4427436823104693 and parameters: {'n_estimators': 1123, 'learning_rate': 0.04472900051220432}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:19:46,082] Trial 14 finished with value: 0.44223826714801445 and parameters: {'n_estimators': 1098, 'learning_rate': 0.0464151908046902}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:20:30,051] Trial 15 finished with value: 0.4420505415162455 and parameters: {'n_estimators': 1115, 'learning_rate': 0.03981465336612663}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:21:07,608] Trial 16 finished with value: 0.4408014440433213 and parameters: {'n_estimators': 876, 'learning_rate': 0.0383195297083737}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:21:34,104] Trial 17 finished with value: 0.42857761732851984 and parameters: {'n_estimators': 585, 'learning_rate': 0.010325846980688731}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:22:20,539] Trial 18 finished with value: 0.4416462093862816 and parameters: {'n_estimators': 1189, 'learning_rate': 0.06607211215698831}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:22:56,767] Trial 19 finished with value: 0.4415451263537906 and parameters: {'n_estimators': 922, 'learning_rate': 0.04089533655574375}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:23:44,990] Trial 20 finished with value: 0.4414873646209386 and parameters: {'n_estimators': 1232, 'learning_rate': 0.03042932445240243}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:24:21,430] Trial 21 finished with value: 0.44218050541516246 and parameters: {'n_estimators': 971, 'learning_rate': 0.049206040134081176}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:25:05,831] Trial 22 finished with value: 0.44192779783393504 and parameters: {'n_estimators': 1190, 'learning_rate': 0.06778343156185047}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:25:28,699] Trial 23 finished with value: 0.43545126353790614 and parameters: {'n_estimators': 530, 'learning_rate': 0.023893318161168336}. Best is trial 13 with value: 0.4427436823104693.
# [I 2024-06-01 00:26:17,153] Trial 24 finished with value: 0.44302527075812276 and parameters: {'n_estimators': 1272, 'learning_rate': 0.04404757058676809}. Best is trial 24 with value: 0.44302527075812276.
# [I 2024-06-01 00:26:58,319] Trial 25 finished with value: 0.44103249097472924 and parameters: {'n_estimators': 1007, 'learning_rate': 0.03753678363735063}. Best is trial 24 with value: 0.44302527075812276.
# [I 2024-06-01 00:27:47,977] Trial 26 finished with value: 0.44230324909747293 and parameters: {'n_estimators': 1267, 'learning_rate': 0.04538827212795582}. Best is trial 24 with value: 0.44302527075812276.
# [I 2024-06-01 00:28:38,219] Trial 27 finished with value: 0.44204332129963897 and parameters: {'n_estimators': 1286, 'learning_rate': 0.03465962761103853}. Best is trial 24 with value: 0.44302527075812276.
# [I 2024-06-01 00:29:25,394] Trial 28 finished with value: 0.44181949458483755 and parameters: {'n_estimators': 1240, 'learning_rate': 0.0775177616077826}. Best is trial 24 with value: 0.44302527075812276.
# [I 2024-06-01 00:30:14,039] Trial 29 finished with value: 0.44223104693140797 and parameters: {'n_estimators': 1297, 'learning_rate': 0.05800483570862891}. Best is trial 24 with value: 0.44302527075812276.

# %%
best_params = study.best_params
best_params
# Out:
# {'n_estimators': 1272, 'learning_rate': 0.04404757058676809}

# %%
# Create a model with best parameters and fit with all data
model = XGBClassifier(**best_params)
model.fit(X, y_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.04404757058676809,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1272, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# ## Making Predictions

# %%
preds = model.predict(X_test)
preds
# Out:
# array([3, 2, 0, ..., 2, 0, 0])

# %%
real_predictions = label_encoder.inverse_transform(preds)
real_predictions
# Out:
# array(['medio-bajo', 'medio-alto', 'alto', ..., 'medio-alto', 'alto',
#        'alto'], dtype=object)

# %%
df_submission = pd.DataFrame({
    'ID': df_test_full.ID,
    'RENDIMIENTO_GLOBAL': real_predictions
})

df_submission.head()
# Out:
#        ID RENDIMIENTO_GLOBAL
# 0  550236         medio-bajo
# 1   98545         medio-alto
# 2  499179               alto
# 3  782980               bajo
# 4  785185               bajo

# %%
df_submission.to_csv('xgb_diff_prep_tuned_v3.csv', index=False)
