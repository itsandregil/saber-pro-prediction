# %% [markdown]
# ## Experimento No 6 - Different Preprocessing

# %% [markdown]
# ### Load data and import libraries

# %%
# In case you're running this in colab
# !pip install optuna

# %%
# Data exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Modeling
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, TargetEncoder
from xgboost import XGBClassifier

# Evaluation
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score

# Hyper-parameter tuning
import optuna

# Configurations
RANDOM_SEED = 42 # For reproducibility

sns.set_palette('pastel')
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 50)

# %%
df_train_full = pd.read_csv('data/train.csv')
df_test_full = pd.read_csv('data/test.csv')
df_train_full.head().T
# Out:
#                                                                        0  \
# ID                                                                904256
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                           ENFERMERIA
# ESTU_PRGM_DEPARTAMENTO                                            BOGOTÁ
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 5.5 millones y menos de 7 millones
# ESTU_HORASSEMANATRABAJA                                Menos de 10 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                     Técnica o tecnológica incompleta
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   Si
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                                            Postgrado
# RENDIMIENTO_GLOBAL                                            medio-alto
#
#                                                                        1  \
# ID                                                                645256
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                              DERECHO
# ESTU_PRGM_DEPARTAMENTO                                         ATLANTICO
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                                                0
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    No
# FAMI_EDUCACIONPADRE                       Técnica o tecnológica completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  No
# FAMI_EDUCACIONMADRE                     Técnica o tecnológica incompleta
# RENDIMIENTO_GLOBAL                                                  bajo
#
#                                                                        2  \
# ID                                                                308367
# PERIODO                                                            20203
# ESTU_PRGM_ACADEMICO                                MERCADEO Y PUBLICIDAD
# ESTU_PRGM_DEPARTAMENTO                                            BOGOTÁ
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                                  Más de 30 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                   Secundaria (Bachillerato) completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  No
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                   Secundaria (Bachillerato) completa
# RENDIMIENTO_GLOBAL                                                  bajo
#
#                                                                        3  \
# ID                                                                470353
# PERIODO                                                            20195
# ESTU_PRGM_ACADEMICO                           ADMINISTRACION DE EMPRESAS
# ESTU_PRGM_DEPARTAMENTO                                         SANTANDER
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 4 millones y menos de 5.5 millones
# ESTU_HORASSEMANATRABAJA                                                0
# FAMI_ESTRATOVIVIENDA                                           Estrato 4
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                                              No sabe
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   No
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                   Secundaria (Bachillerato) completa
# RENDIMIENTO_GLOBAL                                                  alto
#
#                                                                        4
# ID                                                                989032
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                           PSICOLOGIA
# ESTU_PRGM_DEPARTAMENTO                                         ANTIOQUIA
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 2.5 millones y menos de 4 millones
# ESTU_HORASSEMANATRABAJA                              Entre 21 y 30 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                                    Primaria completa
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   Si
# ESTU_PRIVADO_LIBERTAD                                                  N
# ESTU_PAGOMATRICULAPROPIO                                              No
# FAMI_TIENECOMPUTADOR                                                  Si
# FAMI_TIENEINTERNET.1                                                  Si
# FAMI_EDUCACIONMADRE                                    Primaria completa
# RENDIMIENTO_GLOBAL                                            medio-bajo

# %%
df_analysis = df_train_full.copy()

# %%
df_analysis.isna().sum().sort_values(ascending=False)
# Out:
# FAMI_TIENEAUTOMOVIL               43623
# FAMI_TIENELAVADORA                39773
# FAMI_TIENECOMPUTADOR              38103
# FAMI_ESTRATOVIVIENDA              32137
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_TIENEINTERNET.1              26629
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONMADRE               23664
# FAMI_EDUCACIONPADRE               23178
# ESTU_PAGOMATRICULAPROPIO           6498
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ID                                    0
# ESTU_PRIVADO_LIBERTAD                 0
# PERIODO                               0
# ESTU_PRGM_DEPARTAMENTO                0
# ESTU_PRGM_ACADEMICO                   0
# RENDIMIENTO_GLOBAL                    0
# dtype: int64

# %% [markdown]
# ### Preprocessing

# %%
def normalize_text(text: str):
    """Removes any weird character like accents from a string"""
    import unicodedata

    if not pd.isna(text):
        return (
            unicodedata.normalize('NFKD', text)
            .encode('ASCII', 'ignore')
            .decode('utf-8')
        )
    return text

def clean_data(df: pd.DataFrame) -> pd.DataFrame: 
    new_df = df.copy() # Create a copy

    # Drop and clean columns
    new_df.drop(['ID', 'FAMI_TIENEINTERNET.1', 'ESTU_PRIVADO_LIBERTAD'], axis=1, inplace=True)

    # Change data types
    new_df['PERIODO'] = new_df['PERIODO'].astype(str)
    
    # Remove weird characters from values
    for col in ['ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE']:
        new_df[col] = new_df[col].apply(normalize_text)

    # Replace values to make more sense
    new_df['ESTU_HORASSEMANATRABAJA'].replace('0', 'No trabaja', inplace=True)
    new_df['FAMI_EDUCACIONPADRE'].replace(['No Aplica', 'No sabe'], 'Ninguno', inplace=True)
    new_df['FAMI_EDUCACIONMADRE'].replace(['No Aplica', 'No sabe'], 'Ninguno', inplace=True)

    return new_df

def impute_cols(df: pd.DataFrame):
    new_df = df.copy() # Make a copy

    # Impute with own values
    new_df['FAMI_ESTRATOVIVIENDA'] = new_df['FAMI_ESTRATOVIVIENDA'].fillna('Unknown') # 'Sin Estrato' or mode or 'Unknown'
    new_df['ESTU_HORASSEMANATRABAJA'] = new_df['ESTU_HORASSEMANATRABAJA'].fillna('No trabaja') # No trabaja or Unknown
    new_df['FAMI_EDUCACIONPADRE'] = new_df['FAMI_EDUCACIONPADRE'].fillna('Ninguno') # Same as with MADRE
    new_df['FAMI_EDUCACIONMADRE'] = new_df['FAMI_EDUCACIONMADRE'].fillna('Ninguno') # Otra opcion: Ninguno or Unknown
 
    # Select binary columns
    # For VALORMATRICULA values could be 'No pago matricula' or Mode or Unknown (We'll go we the mode first)
    binary_cols = [col for col in new_df.columns if new_df[col].nunique() == 2]
    for col in binary_cols + ['ESTU_VALORMATRICULAUNIVERSIDAD']:
        col_mode = new_df[col].mode()[0]
        new_df[col] = new_df[col].fillna(col_mode)

    return new_df

# %%
# Clean the training and testing datasets
df_train = clean_data(df_train_full)
df_test = clean_data(df_test_full)

# %%
# Impute values in training and testing datasets
df_train = impute_cols(df_train)
df_test = impute_cols(df_test)

# %%
df_train.shape
# Out:
# (692500, 14)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   PERIODO                         692500 non-null  object
#  1   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  2   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  3   ESTU_VALORMATRICULAUNIVERSIDAD  692500 non-null  object
#  4   ESTU_HORASSEMANATRABAJA         692500 non-null  object
#  5   FAMI_ESTRATOVIVIENDA            692500 non-null  object
#  6   FAMI_TIENEINTERNET              692500 non-null  object
#  7   FAMI_EDUCACIONPADRE             692500 non-null  object
#  8   FAMI_TIENELAVADORA              692500 non-null  object
#  9   FAMI_TIENEAUTOMOVIL             692500 non-null  object
#  10  ESTU_PAGOMATRICULAPROPIO        692500 non-null  object
#  11  FAMI_TIENECOMPUTADOR            692500 non-null  object
#  12  FAMI_EDUCACIONMADRE             692500 non-null  object
#  13  RENDIMIENTO_GLOBAL              692500 non-null  object
# dtypes: object(14)
# memory usage: 74.0+ MB

# %% [markdown]
# #### Encoding

# %%
# Define encoders in a global scope to use them
# after they were fitted with the data.
label_encoder = LabelEncoder()
target_encoder = TargetEncoder(target_type='multiclass', random_state=RANDOM_SEED)

def preprocess_data(X: pd.DataFrame, y: pd.Series = None) -> pd.DataFrame():
    """
    Turns features and target into numeric values applying an encoding for each
    column.
    """
    X = X.copy() # Make copy of the features
    y_encoded = None
    
    high_card_cols = ['ESTU_PRGM_ACADEMICO']
    # Check if target was provided
    if y is not None:
        # Label encoding
        y_encoded = pd.Series(label_encoder.fit_transform(y))
        
        # Target encoding for training using the encoded labels
        # We need to fit and transform the data here.
        target_encoder.fit(X[high_card_cols], y_encoded)
        new_features_names = target_encoder.get_feature_names_out()
        df_target_encoded = pd.DataFrame(target_encoder.transform(X[high_card_cols]), columns=new_features_names)
        
        X = pd.concat([X.drop('ESTU_PRGM_ACADEMICO', axis=1), df_target_encoded], axis=1)
    else:
        # Target encoding for testing dataset just using transform
        new_features_names = target_encoder.get_feature_names_out()
        df_target_encoded = pd.DataFrame(target_encoder.transform(X[high_card_cols]), columns=new_features_names)
        X = pd.concat([X.drop('ESTU_PRGM_ACADEMICO', axis=1), df_target_encoded], axis=1)
        

    # Ordinal encoding
    ord_encoder = OrdinalEncoder() # Ordinal Encoder
    ord_cols = ['FAMI_ESTRATOVIVIENDA','ESTU_PRGM_DEPARTAMENTO']    
    df_ordinal = pd.DataFrame(ord_encoder.fit_transform(X[ord_cols]), columns=ord_cols)
    
    for col in ord_cols:
        max_val = df_ordinal[col].max()
        df_ordinal[col] = df_ordinal[col].map(lambda x: x / max_val) # Normalize values 0 - 1

    X = pd.concat([X.drop(ord_cols, axis=1), df_ordinal], axis=1)

    # Binary encoding
    bin_cols = [col for col in X.columns if X[col].nunique() == 2]

    for col in bin_cols:
        X[col] = X[col].replace({'Si': 1, 'No': 0})
    
    # One-hot encoding
    X = pd.get_dummies(X, dtype=int)

    return X, y_encoded

# %%
# Split train data into features and target
X = df_train.drop('RENDIMIENTO_GLOBAL', axis=1)
y = df_train.RENDIMIENTO_GLOBAL

# %%
# Encode features and target (for training dataset)
X, y_encoded = preprocess_data(X, y)
X_test, _ = preprocess_data(X=df_test)

# %%
X.shape, X_test.shape
# Out:
# ((692500, 53), (296786, 53))

# %%
type(y_encoded)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Model Creation
#
# At this point we are going to try a **XGBClassifier** to see how the preprocessing improve the accuracy
#
# - The optimal number of estimators will be automatically set by the model using `early_stopping_rounds`

# %% [markdown]
# ## Hyper-parameters Tuning

# %%
def xgb_objective(trial):

    # Split data
    X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=RANDOM_SEED)
    
    # Create params
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-2, 0.4),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 100.0),
        'gamma': trial.suggest_loguniform('gamma', 0.01, 2.0)
    }
    # Set params to the model and train the new model
    model = XGBClassifier(
        objetive='multi:softmax',
        num_class=4,
        **params,
        subsample=0.9,
        colsample_bytree=0.5,
    )

    # Fit the model
    model.fit(X_train, y_train)

    # Evaluate
    preds = model.predict(X_val)
    acc = accuracy_score(y_val, preds)

    return acc

# %%
study = optuna.create_study(direction='maximize')
study.optimize(xgb_objective, n_trials=20)
# Out:
# [I 2024-06-01 17:46:06,932] A new study created in memory with name: no-name-6dc1bfb3-a795-419a-b087-a252a67eeea7
# [I 2024-06-01 17:46:11,450] Trial 0 finished with value: 0.4343465703971119 and parameters: {'learning_rate': 0.11437749304303745, 'max_depth': 6, 'reg_alpha': 1.399118630762639, 'gamma': 1.9280983686849766}. Best is trial 0 with value: 0.4343465703971119.
# [I 2024-06-01 17:46:16,340] Trial 1 finished with value: 0.439884476534296 and parameters: {'learning_rate': 0.20915748815070764, 'max_depth': 7, 'reg_alpha': 5.620829956316611, 'gamma': 0.042445884381707766}. Best is trial 1 with value: 0.439884476534296.
# [I 2024-06-01 17:46:22,808] Trial 2 finished with value: 0.4276606498194946 and parameters: {'learning_rate': 0.010939459646895787, 'max_depth': 9, 'reg_alpha': 0.2840852227171533, 'gamma': 0.21071254909546183}. Best is trial 1 with value: 0.439884476534296.
# [I 2024-06-01 17:46:40,306] Trial 3 finished with value: 0.4087148014440433 and parameters: {'learning_rate': 0.32226452734604055, 'max_depth': 18, 'reg_alpha': 0.0036890370283409355, 'gamma': 0.06041632713521229}. Best is trial 1 with value: 0.439884476534296.
# [I 2024-06-01 17:46:49,732] Trial 4 finished with value: 0.44218772563176895 and parameters: {'learning_rate': 0.08455420196961522, 'max_depth': 15, 'reg_alpha': 8.237424203367677, 'gamma': 0.02833218583175966}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:46:56,930] Trial 5 finished with value: 0.43046209386281586 and parameters: {'learning_rate': 0.01148440506987383, 'max_depth': 10, 'reg_alpha': 0.10271821312875479, 'gamma': 0.24185777989451573}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:02,308] Trial 6 finished with value: 0.43046209386281586 and parameters: {'learning_rate': 0.050038683012083036, 'max_depth': 7, 'reg_alpha': 3.2028730275176858, 'gamma': 0.01222311108655593}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:06,939] Trial 7 finished with value: 0.4253429602888087 and parameters: {'learning_rate': 0.049040260703342574, 'max_depth': 6, 'reg_alpha': 80.89651698244347, 'gamma': 0.01320449379688511}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:10,273] Trial 8 finished with value: 0.4175595667870036 and parameters: {'learning_rate': 0.05192725490703192, 'max_depth': 3, 'reg_alpha': 1.2832801072889972, 'gamma': 0.41080049946725844}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:22,833] Trial 9 finished with value: 0.4394368231046931 and parameters: {'learning_rate': 0.03537293234004099, 'max_depth': 17, 'reg_alpha': 0.005756957856472395, 'gamma': 0.8833442505121525}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:29,711] Trial 10 finished with value: 0.43735740072202167 and parameters: {'learning_rate': 0.1266672475983542, 'max_depth': 14, 'reg_alpha': 86.06900256247816, 'gamma': 0.05106265992802652}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:37,988] Trial 11 finished with value: 0.4375595667870036 and parameters: {'learning_rate': 0.3775879115280687, 'max_depth': 14, 'reg_alpha': 12.332072198104171, 'gamma': 0.04034852646847098}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:45,979] Trial 12 finished with value: 0.44153790613718413 and parameters: {'learning_rate': 0.1596643305857326, 'max_depth': 13, 'reg_alpha': 11.162779719109976, 'gamma': 0.027412883469753364}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:47:53,847] Trial 13 finished with value: 0.4411768953068592 and parameters: {'learning_rate': 0.1161763692620916, 'max_depth': 14, 'reg_alpha': 21.223278990440164, 'gamma': 0.02182365731473796}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:48:11,552] Trial 14 finished with value: 0.4384115523465704 and parameters: {'learning_rate': 0.02472761146684, 'max_depth': 16, 'reg_alpha': 0.10331177484871941, 'gamma': 0.09710106654890925}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:48:19,095] Trial 15 finished with value: 0.4412996389891697 and parameters: {'learning_rate': 0.18543834709110937, 'max_depth': 12, 'reg_alpha': 28.588045227728067, 'gamma': 0.024951344036100043}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:48:43,528] Trial 16 finished with value: 0.42976895306859203 and parameters: {'learning_rate': 0.07193965786187786, 'max_depth': 20, 'reg_alpha': 0.6326888317285303, 'gamma': 0.08968185773431564}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:48:51,526] Trial 17 finished with value: 0.44109025270758123 and parameters: {'learning_rate': 0.08732459707475192, 'max_depth': 12, 'reg_alpha': 5.74939647011105, 'gamma': 0.021500200149524685}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:49:03,123] Trial 18 finished with value: 0.4272635379061372 and parameters: {'learning_rate': 0.20960604667386135, 'max_depth': 15, 'reg_alpha': 0.01607031697288313, 'gamma': 0.15044445331656123}. Best is trial 4 with value: 0.44218772563176895.
# [I 2024-06-01 17:49:12,017] Trial 19 finished with value: 0.4332057761732852 and parameters: {'learning_rate': 0.025391421681936043, 'max_depth': 20, 'reg_alpha': 26.71094407224073, 'gamma': 0.010512226652625217}. Best is trial 4 with value: 0.44218772563176895.

# %%
best_params = study.best_params
best_params
# Out:
# {'learning_rate': 0.08455420196961522,
#  'max_depth': 15,
#  'reg_alpha': 8.237424203367677,
#  'gamma': 0.02833218583175966}

# %%
 # Split data
X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2)

# %%
# Create a model with best parameters and fit with all data
model = XGBClassifier(
    seed=RANDOM_SEED,
    objetive='multi:softmax',
    n_estimators=1300,
    num_class=4,
    subsample=0.9,
    colsample_bytree=0.5,
    **best_params
)

model.fit(
    X_train, y_train,
    verbose=True,
    early_stopping_rounds=10,
    eval_set=[(X_val, y_val)]
)
# Out:
# [0]	validation_0-mlogloss:1.36998
# [1]	validation_0-mlogloss:1.35617
# [2]	validation_0-mlogloss:1.34318
# [3]	validation_0-mlogloss:1.33211
# [4]	validation_0-mlogloss:1.32176
# [5]	validation_0-mlogloss:1.31372
# [6]	validation_0-mlogloss:1.30514
# [7]	validation_0-mlogloss:1.29644
# [8]	validation_0-mlogloss:1.28887
# [9]	validation_0-mlogloss:1.28238
# [10]	validation_0-mlogloss:1.27635
# [11]	validation_0-mlogloss:1.27033
# [12]	validation_0-mlogloss:1.26560
# [13]	validation_0-mlogloss:1.26018
# [14]	validation_0-mlogloss:1.25514
# [15]	validation_0-mlogloss:1.25092
# [16]	validation_0-mlogloss:1.24709
# [17]	validation_0-mlogloss:1.24350
# [18]	validation_0-mlogloss:1.24077
# [19]	validation_0-mlogloss:1.23793
# [20]	validation_0-mlogloss:1.23529
# [21]	validation_0-mlogloss:1.23264
# [22]	validation_0-mlogloss:1.23029
# [23]	validation_0-mlogloss:1.22841
# [24]	validation_0-mlogloss:1.22641
# [25]	validation_0-mlogloss:1.22447
# [26]	validation_0-mlogloss:1.22280
# [27]	validation_0-mlogloss:1.22130
# [28]	validation_0-mlogloss:1.21972
# [29]	validation_0-mlogloss:1.21844
# [30]	validation_0-mlogloss:1.21706
# [31]	validation_0-mlogloss:1.21575
# [32]	validation_0-mlogloss:1.21435
# [33]	validation_0-mlogloss:1.21311
# [34]	validation_0-mlogloss:1.21201
# [35]	validation_0-mlogloss:1.21071
# [36]	validation_0-mlogloss:1.20996
# [37]	validation_0-mlogloss:1.20893
# [38]	validation_0-mlogloss:1.20805
# [39]	validation_0-mlogloss:1.20732
# [40]	validation_0-mlogloss:1.20643
# [41]	validation_0-mlogloss:1.20574
# [42]	validation_0-mlogloss:1.20487
# [43]	validation_0-mlogloss:1.20417
# [44]	validation_0-mlogloss:1.20342
# [45]	validation_0-mlogloss:1.20294
# [46]	validation_0-mlogloss:1.20211
# [47]	validation_0-mlogloss:1.20147
# [48]	validation_0-mlogloss:1.20055
# [49]	validation_0-mlogloss:1.19982
# [50]	validation_0-mlogloss:1.19932
# [51]	validation_0-mlogloss:1.19900
# [52]	validation_0-mlogloss:1.19841
# [53]	validation_0-mlogloss:1.19803
# [54]	validation_0-mlogloss:1.19756
# [55]	validation_0-mlogloss:1.19703
# [56]	validation_0-mlogloss:1.19671
# [57]	validation_0-mlogloss:1.19641
# [58]	validation_0-mlogloss:1.19595
# [59]	validation_0-mlogloss:1.19557
# [60]	validation_0-mlogloss:1.19525
# [61]	validation_0-mlogloss:1.19492
# [62]	validation_0-mlogloss:1.19466
# [63]	validation_0-mlogloss:1.19446
# [64]	validation_0-mlogloss:1.19422
# [65]	validation_0-mlogloss:1.19403
# [66]	validation_0-mlogloss:1.19371
# [67]	validation_0-mlogloss:1.19337
# [68]	validation_0-mlogloss:1.19316
# [69]	validation_0-mlogloss:1.19293
# [70]	validation_0-mlogloss:1.19279
# [71]	validation_0-mlogloss:1.19258
# [72]	validation_0-mlogloss:1.19234
# [73]	validation_0-mlogloss:1.19223
# [74]	validation_0-mlogloss:1.19214
# [75]	validation_0-mlogloss:1.19184
# [76]	validation_0-mlogloss:1.19155
# [77]	validation_0-mlogloss:1.19141
# [78]	validation_0-mlogloss:1.19121
# [79]	validation_0-mlogloss:1.19091
# [80]	validation_0-mlogloss:1.19081
# [81]	validation_0-mlogloss:1.19060
# [82]	validation_0-mlogloss:1.19034
# [83]	validation_0-mlogloss:1.19024
# [84]	validation_0-mlogloss:1.19004
# [85]	validation_0-mlogloss:1.18995
# [86]	validation_0-mlogloss:1.18984
# [87]	validation_0-mlogloss:1.18965
# [88]	validation_0-mlogloss:1.18942
# [89]	validation_0-mlogloss:1.18926
# [90]	validation_0-mlogloss:1.18914
# [91]	validation_0-mlogloss:1.18904
# [92]	validation_0-mlogloss:1.18888
# [93]	validation_0-mlogloss:1.18877
# [94]	validation_0-mlogloss:1.18865
# [95]	validation_0-mlogloss:1.18857
# [96]	validation_0-mlogloss:1.18840
# [97]	validation_0-mlogloss:1.18833
# [98]	validation_0-mlogloss:1.18829
# [99]	validation_0-mlogloss:1.18808
# [100]	validation_0-mlogloss:1.18801
# [101]	validation_0-mlogloss:1.18794
# [102]	validation_0-mlogloss:1.18784
# [103]	validation_0-mlogloss:1.18774
# [104]	validation_0-mlogloss:1.18770
# [105]	validation_0-mlogloss:1.18761
# [106]	validation_0-mlogloss:1.18749
# [107]	validation_0-mlogloss:1.18744
# [108]	validation_0-mlogloss:1.18739
# [109]	validation_0-mlogloss:1.18727
# [110]	validation_0-mlogloss:1.18718
# [111]	validation_0-mlogloss:1.18714
# [112]	validation_0-mlogloss:1.18710
# [113]	validation_0-mlogloss:1.18706
# [114]	validation_0-mlogloss:1.18694
# [115]	validation_0-mlogloss:1.18689
# [116]	validation_0-mlogloss:1.18685
# [117]	validation_0-mlogloss:1.18679
# [118]	validation_0-mlogloss:1.18673
# [119]	validation_0-mlogloss:1.18667
# [120]	validation_0-mlogloss:1.18667
# [121]	validation_0-mlogloss:1.18666
# [122]	validation_0-mlogloss:1.18659
# [123]	validation_0-mlogloss:1.18649
# [124]	validation_0-mlogloss:1.18645
# [125]	validation_0-mlogloss:1.18643
# [126]	validation_0-mlogloss:1.18638
# [127]	validation_0-mlogloss:1.18632
# [128]	validation_0-mlogloss:1.18625
# [129]	validation_0-mlogloss:1.18621
# [130]	validation_0-mlogloss:1.18622
# [131]	validation_0-mlogloss:1.18618
# [132]	validation_0-mlogloss:1.18616
# [133]	validation_0-mlogloss:1.18608
# [134]	validation_0-mlogloss:1.18601
# [135]	validation_0-mlogloss:1.18596
# [136]	validation_0-mlogloss:1.18589
# [137]	validation_0-mlogloss:1.18589
# [138]	validation_0-mlogloss:1.18581
# [139]	validation_0-mlogloss:1.18577
# [140]	validation_0-mlogloss:1.18573
# [141]	validation_0-mlogloss:1.18565
# [142]	validation_0-mlogloss:1.18561
# [143]	validation_0-mlogloss:1.18555
# [144]	validation_0-mlogloss:1.18553
# [145]	validation_0-mlogloss:1.18552
# [146]	validation_0-mlogloss:1.18552
# [147]	validation_0-mlogloss:1.18552
# [148]	validation_0-mlogloss:1.18548
# [149]	validation_0-mlogloss:1.18549
# [150]	validation_0-mlogloss:1.18547
# [151]	validation_0-mlogloss:1.18545
# [152]	validation_0-mlogloss:1.18545
# [153]	validation_0-mlogloss:1.18546
# [154]	validation_0-mlogloss:1.18547
# [155]	validation_0-mlogloss:1.18545
# [156]	validation_0-mlogloss:1.18541
# [157]	validation_0-mlogloss:1.18540
# [158]	validation_0-mlogloss:1.18540
# [159]	validation_0-mlogloss:1.18537
# [160]	validation_0-mlogloss:1.18535
# [161]	validation_0-mlogloss:1.18533
# [162]	validation_0-mlogloss:1.18532
# [163]	validation_0-mlogloss:1.18529
# [164]	validation_0-mlogloss:1.18527
# [165]	validation_0-mlogloss:1.18525
# [166]	validation_0-mlogloss:1.18526
# [167]	validation_0-mlogloss:1.18522
# [168]	validation_0-mlogloss:1.18522
# [169]	validation_0-mlogloss:1.18525
# [170]	validation_0-mlogloss:1.18524
# [171]	validation_0-mlogloss:1.18523
# [172]	validation_0-mlogloss:1.18524
# [173]	validation_0-mlogloss:1.18521
# [174]	validation_0-mlogloss:1.18519
# [175]	validation_0-mlogloss:1.18518
# [176]	validation_0-mlogloss:1.18518
# [177]	validation_0-mlogloss:1.18517
# [178]	validation_0-mlogloss:1.18518
# [179]	validation_0-mlogloss:1.18515
# [180]	validation_0-mlogloss:1.18514
# [181]	validation_0-mlogloss:1.18510
# [182]	validation_0-mlogloss:1.18510
# [183]	validation_0-mlogloss:1.18513
# [184]	validation_0-mlogloss:1.18511
# [185]	validation_0-mlogloss:1.18514
# [186]	validation_0-mlogloss:1.18515
# [187]	validation_0-mlogloss:1.18516
# [188]	validation_0-mlogloss:1.18517
# [189]	validation_0-mlogloss:1.18518
# [190]	validation_0-mlogloss:1.18519
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.02833218583175966, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.08455420196961522,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1300, n_jobs=None, num_class=4,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ## Making Predictions

# %%
preds = model.predict(X_test)
preds
# Out:
# array([3, 2, 0, ..., 2, 0, 0])

# %%
real_predictions = label_encoder.inverse_transform(preds)
real_predictions
# Out:
# array(['medio-bajo', 'medio-alto', 'alto', ..., 'medio-alto', 'alto',
#        'alto'], dtype=object)

# %%
df_submission = pd.DataFrame({
    'ID': df_test_full.ID,
    'RENDIMIENTO_GLOBAL': real_predictions
})

df_submission.head()
# Out:
#        ID RENDIMIENTO_GLOBAL
# 0  550236         medio-bajo
# 1   98545         medio-alto
# 2  499179               alto
# 3  782980               bajo
# 4  785185               bajo

# %%
df_submission.to_csv('xgb_tuning_l1.csv', index=False)
